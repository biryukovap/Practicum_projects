# %% [markdown]
# # Разработка модели для удержания клиентов магазина "██████"

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#1.-Описание-задачи" data-toc-modified-id="1.-Описание-задачи-1">1. Описание задачи</a></span></li><li><span><a href="#2.-Описание-данных" data-toc-modified-id="2.-Описание-данных-2">2. Описание данных</a></span><ul class="toc-item"><li><span><a href="#██████" data-toc-modified-id="██████-2.1">██████</a></span></li><li><span><a href="#██████" data-toc-modified-id="██████-2.2">██████</a></span></li><li><span><a href="#██████" data-toc-modified-id="██████-2.3">██████</a></span></li><li><span><a href="#██████" data-toc-modified-id="██████-2.4">██████</a></span></li></ul></li><li><span><a href="#Шаг-1.-Загрузка-данных" data-toc-modified-id="Шаг-1.-Загрузка-данных-3">Шаг 1. Загрузка данных</a></span><ul class="toc-item"><li><span><a href="#Загружаем-данные" data-toc-modified-id="Загружаем-данные-3.1">Загружаем данные</a></span></li><li><span><a href="#Проверяем,-что-данные-в-таблицах-соответствуют-описанию" data-toc-modified-id="Проверяем,-что-данные-в-таблицах-соответствуют-описанию-3.2">Проверяем, что данные в таблицах соответствуют описанию</a></span><ul class="toc-item"><li><span><a href="#██████" data-toc-modified-id="██████-3.2.1"><code>██████</code></a></span></li><li><span><a href="#██████" data-toc-modified-id="██████-3.2.2"><code>██████</code></a></span></li><li><span><a href="#██████" data-toc-modified-id="██████-3.2.3"><code>██████</code></a></span></li><li><span><a href="#██████" data-toc-modified-id="██████-3.2.4"><code>██████</code></a></span></li></ul></li></ul></li><li><span><a href="#Шаг-2.-Предобработка-данных" data-toc-modified-id="Шаг-2.-Предобработка-данных-4">Шаг 2. Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#██████" data-toc-modified-id="██████-4.1"><code>██████</code></a></span></li><li><span><a href="#██████" data-toc-modified-id="██████-4.2"><code>██████</code></a></span></li><li><span><a href="#██████" data-toc-modified-id="██████-4.3"><code>██████</code></a></span></li><li><span><a href="#██████" data-toc-modified-id="██████-4.4"><code>██████</code></a></span></li></ul></li><li><span><a href="#Шаг-3.-Исследовательский-анализ-данных" data-toc-modified-id="Шаг-3.-Исследовательский-анализ-данных-5">Шаг 3. Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Описательная-статистика" data-toc-modified-id="Описательная-статистика-5.1">Описательная статистика</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.1.1">Вывод</a></span></li></ul></li><li><span><a href="#Строим-графики" data-toc-modified-id="Строим-графики-5.2">Строим графики</a></span><ul class="toc-item"><li><span><a href="#██████" data-toc-modified-id="██████-5.2.1"><code>██████</code></a></span><ul class="toc-item"><li><span><a href="#Графики" data-toc-modified-id="Графики-5.2.1.1">Графики</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5.2.1.2">Выводы</a></span></li></ul></li><li><span><a href="#██████" data-toc-modified-id="██████-5.2.2"><code>██████</code></a></span><ul class="toc-item"><li><span><a href="#Категориальные-признаки" data-toc-modified-id="Категориальные-признаки-5.2.2.1">Категориальные признаки</a></span></li><li><span><a href="#Количественные-признаки" data-toc-modified-id="Количественные-признаки-5.2.2.2">Количественные признаки</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5.2.2.3">Выводы</a></span></li></ul></li><li><span><a href="#██████" data-toc-modified-id="██████-5.2.3"><code>██████</code></a></span><ul class="toc-item"><li><span><a href="#Графики" data-toc-modified-id="Графики-5.2.3.1">Графики</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5.2.3.2">Выводы</a></span></li></ul></li><li><span><a href="#money" data-toc-modified-id="money-5.2.4"><code>money</code></a></span><ul class="toc-item"><li><span><a href="#Графики" data-toc-modified-id="Графики-5.2.4.1">Графики</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5.2.4.2">Выводы</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Шаг-4.-Объединение-таблиц" data-toc-modified-id="Шаг-4.-Объединение-таблиц-6">Шаг 4. Объединение таблиц</a></span></li><li><span><a href="#Шаг-5.-Корреляционный-анализ" data-toc-modified-id="Шаг-5.-Корреляционный-анализ-7">Шаг 5. Корреляционный анализ</a></span><ul class="toc-item"><li><span><a href="#Построение-матрицы-phik" data-toc-modified-id="Построение-матрицы-phik-7.1">Построение матрицы phik</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.2">Вывод</a></span></li></ul></li><li><span><a href="#Шаг-6.-Использование-пайплайнов" data-toc-modified-id="Шаг-6.-Использование-пайплайнов-8">Шаг 6. Использование пайплайнов</a></span><ul class="toc-item"><li><span><a href="#Создание-пайплайнов" data-toc-modified-id="Создание-пайплайнов-8.1">Создание пайплайнов</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-8.2">Вывод</a></span></li></ul></li><li><span><a href="#Шаг-7.-Анализ-важности-признаков" data-toc-modified-id="Шаг-7.-Анализ-важности-признаков-9">Шаг 7. Анализ важности признаков</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-9.1">Выводы</a></span></li><li><span><a href="#Шаг-8.-Сегментация-покупателей" data-toc-modified-id="Шаг-8.-Сегментация-покупателей-9.2">Шаг 8. Сегментация покупателей</a></span></li><li><span><a href="#Анализ-количественных-признаков" data-toc-modified-id="Анализ-количественных-признаков-9.3">Анализ количественных признаков</a></span></li><li><span><a href="#Анализ-качественных-признаков" data-toc-modified-id="Анализ-качественных-признаков-9.4">Анализ качественных признаков</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-9.5">Выводы</a></span></li></ul></li><li><span><a href="#Шаг-9.-Общий-вывод" data-toc-modified-id="Шаг-9.-Общий-вывод-10">Шаг 9. Общий вывод</a></span><ul class="toc-item"><li><span><a href="#Описание-задачи" data-toc-modified-id="Описание-задачи-10.1">Описание задачи</a></span></li><li><span><a href="#Описание-исходных-данных-и-проведённой-предобработки" data-toc-modified-id="Описание-исходных-данных-и-проведённой-предобработки-10.2">Описание исходных данных и проведённой предобработки</a></span></li><li><span><a href="#Что-сделано-для-поиска-лучшей-модели" data-toc-modified-id="Что-сделано-для-поиска-лучшей-модели-10.3">Что сделано для поиска лучшей модели</a></span></li><li><span><a href="#Лучшая-модель" data-toc-modified-id="Лучшая-модель-10.4">Лучшая модель</a></span></li><li><span><a href="#Выводы-и-дополнительные-предложения-для-сегмента-покупателей" data-toc-modified-id="Выводы-и-дополнительные-предложения-для-сегмента-покупателей-10.5">Выводы и дополнительные предложения для сегмента покупателей</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## 1. Описание задачи
#
# Интернет-магазин «██████» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться.\
# **Задача**: разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.

# %% [markdown]
# ## 2. Описание данных
#
# ### ██████
# Таблица, которая содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
#
# ### ██████
# Таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
#
#
# ### ██████
# Таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
#
# ### ██████
# Таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.

# %% [markdown]
# ## Шаг 1. Загрузка данных

# %%
#подключение библиотек

#чтобы убрать ворнинги
import warnings
warnings.filterwarnings('ignore')

#работа с датафреймами и визуализацией
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import phik
from phik.report import plot_correlation_matrix
import shap

#пайплайн
from sklearn.pipeline import Pipeline

#классы для подготовки данных
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import (LabelEncoder,
                                   OneHotEncoder,
                                   OrdinalEncoder,
                                   StandardScaler,
                                   MinMaxScaler,
                                   RobustScaler)
#класс для работы с пропусками
from sklearn.impute import SimpleImputer

#функция для работы с метриками
from sklearn.metrics import roc_auc_score

#нужные модели
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.dummy import DummyClassifier

RANDOM_STATE = 42
TEST_SIZE = 0.25

# %% [markdown]
# ### Загружаем данные

# %%
try:
    market_file = pd.read_csv('██████.csv', sep=',', decimal=',')
    market_money = pd.read_csv('██████.csv', sep=',', decimal=',')
    market_time = pd.read_csv('██████.csv', sep=',', decimal=',')
    money = pd.read_csv('██████.csv', sep=';', decimal=',')
except:
    market_file = pd.read_csv('████████████.csv', sep=',', decimal=',')
    market_money = pd.read_csv('████████████.csv', sep=',', decimal=',')
    market_time = pd.read_csv('████████████.csv', sep=',', decimal=',')
    money = pd.read_csv('████████████.csv', sep=';', decimal=',')

# %% [markdown]
# ### Проверяем, что данные в таблицах соответствуют описанию

# %%
#функция для вывода информации о датасетах
def data_main_info(data):
    try:
        print('-------------------------------------------------------------------------------')
        print('Первые 3 строки:')
        print('-------------------------------------------------------------------------------')
        display(data.head(3))
        print('-------------------------------------------------------------------------------')
        print('Описание данных:')
        print('-------------------------------------------------------------------------------')
        display(data.describe(include = "all"))
        print('-------------------------------------------------------------------------------')
        print('Общая информация о датафрейме')
        print('-------------------------------------------------------------------------------')
        display(data.info())
        print('-------------------------------------------------------------------------------')
        print('Исследование пропусков')
        print('-------------------------------------------------------------------------------')
        display(pd.DataFrame({'nan_qty' : data.isna().sum().sort_values(ascending=False), 
                  'nan_%' : round((data.isna().mean()*100), 1).sort_values(ascending=False)}))
        print('-------------------------------------------------------------------------------')
        print('Доля явных дубликатов')
        print('-------------------------------------------------------------------------------')
        print(f"{data.duplicated().sum() / data.shape[0] * 100:.2f}%")
    except:
        return 'Проверьте параметры'

# %% [markdown]
# #### `██████`

# %%
#выведем основную информацию
data_main_info(██████)
# Out:
# -------------------------------------------------------------------------------
# Первые 3 строки:
# -------------------------------------------------------------------------------
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
#
#   Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность Акционные_покупки  \
# 0                3.4                     5           121               0.0
# 1                4.4                     4           819              0.75
# 2                4.9                     3           539              0.14
#
#   Популярная_категория  Средний_просмотр_категорий_за_визит  \
# 0     Товары для детей                                    6
# 1     Товары для детей                                    4
# ...

# %% [markdown]
# ###### Вывод
# Видим 1300 наблюдений, количество колонок совпадает с ожидаемым, явных дубликатов нет, но нужно:
# 1. Исправить форматы (`Маркет_актив_6_мес` на `float`, `Акционные_покупки` на `float`)
# 2. Проверить уникальные значения в столбце `Тип сервиса`, чтобы избежать неявных дубликатов
# 3. Переименовать колонки змеиным_языком и нижним регистром

# %% [markdown]
# #### `██████`

# %%
data_main_info(██████)
# Out:
# -------------------------------------------------------------------------------
# Первые 3 строки:
# -------------------------------------------------------------------------------
#        id               Период Выручка
# 0  215348  препредыдущий_месяц     0.0
# 1  215348        текущий_месяц  3293.1
# 2  215348     предыдущий_месяц     0.0
# -------------------------------------------------------------------------------
# Описание данных:
# -------------------------------------------------------------------------------
#                    id         Период Выручка
# count     3900.000000           3900    3900
# unique            NaN              3    2776
# top               NaN  текущий_месяц  4729.0
# freq              NaN           1300       8
# mean    215997.500000            NaN     NaN
# std        375.325686            NaN     NaN
# min     215348.000000            NaN     NaN
# 25%     215672.750000            NaN     NaN
# 50%     215997.500000            NaN     NaN
# ...

# %% [markdown]
# ###### Вывод
# Видим 3900 наблюдений, количество колонок совпадает с ожидаемым, явных дубликатов нет, выручку нужно перевести во `float`, колонки в нижний регистр.

# %% [markdown]
# #### `██████`

# %%
data_main_info(██████)
# Out:
# -------------------------------------------------------------------------------
# Первые 3 строки:
# -------------------------------------------------------------------------------
#        id            Период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# -------------------------------------------------------------------------------
# Описание данных:
# -------------------------------------------------------------------------------
#                    id         Период        минут
# count     2600.000000           2600  2600.000000
# unique            NaN              2          NaN
# top               NaN  текущий_месяц          NaN
# freq              NaN           1300          NaN
# mean    215997.500000            NaN    13.336154
# std        375.349754            NaN     4.080198
# min     215348.000000            NaN     4.000000
# 25%     215672.750000            NaN    10.000000
# ...

# %% [markdown]
# ###### Вывод
# Видим 2600 наблюдений, количество колонок совпадает с ожидаемым, явных дубликатов нет, форматы верные, но нужно исправить опечатку в значении периода и перевести колонки в нижний регистр.

# %% [markdown]
# #### `██████`

# %%
data_main_info(██████)
# Out:
# -------------------------------------------------------------------------------
# Первые 3 строки:
# -------------------------------------------------------------------------------
#        id  Прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# -------------------------------------------------------------------------------
# Описание данных:
# -------------------------------------------------------------------------------
#                   id      Прибыль
# count    1300.000000  1300.000000
# mean   215997.500000     3.996631
# std       375.421985     1.013722
# min    215348.000000     0.860000
# 25%    215672.750000     3.300000
# 50%    215997.500000     4.045000
# 75%    216322.250000     4.670000
# max    216647.000000     7.430000
# -------------------------------------------------------------------------------
# Общая информация о датафрейме
# -------------------------------------------------------------------------------
# ...

# %% [markdown]
# ###### Вывод
# Видим 1300 наблюдений, количество колонок совпадает с ожидаемым, явных дубликатов нет, форматы верные, но нужно перевести колонки в нижний регистр.

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %% [markdown]
# ### `██████`
#
# 1. Исправим форматы (`Маркет_актив_6_мес` на `float`, `Акционные_покупки` на `float`)

# %%
██████[['Маркет_актив_6_мес', 'Акционные_покупки']] = (
    ██████[['Маркет_актив_6_мес', 'Акционные_покупки']].astype('float64'))

██████.dtypes
# Out:
# id                                       int64
# Покупательская активность               object
# Тип сервиса                             object
# Разрешить сообщать                      object
# Маркет_актив_6_мес                     float64
# Маркет_актив_тек_мес                     int64
# Длительность                             int64
# Акционные_покупки                      float64
# Популярная_категория                    object
# Средний_просмотр_категорий_за_визит      int64
# Неоплаченные_продукты_штук_квартал       int64
# Ошибка_сервиса                           int64
# Страниц_за_визит                         int64
# dtype: object

# %% [markdown]
# 2. Проверим уникальные значения в столбце `Тип сервиса`, чтобы избежать неявных дубликатов

# %%
██████['Тип сервиса'].unique()
# Out:
# array(['премиум', 'стандартт', 'стандарт'], dtype=object)

# %%
# меняем 'стандартт' на 'стандарт'
██████['Тип сервиса'] = ██████['Тип сервиса'].replace('стандартт', 'стандарт')
██████['Тип сервиса'].unique()
# Out:
# array(['премиум', 'стандарт'], dtype=object)

# %%
#проверим, появились ли дубликаты
██████.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 3. Переименуем колонки змеиным_языком и переведем в нижний регистр

# %%
██████ = ██████.rename(columns = {'Покупательская активность':'Покупательская_активность',
                                           'Тип сервиса':'Тип_сервиса',
                                           'Разрешить сообщать': 'Разрешить_сообщать'})

██████.columns = ██████.columns.str.lower()

# %% [markdown]
# ### `██████`
#
# Переводим выручку в числовое значение.

# %%
██████['Выручка'] = ██████['Выручка'].astype('float64')
██████.dtypes

██████.columns = ██████.columns.str.lower()

# %% [markdown]
# ### `██████`
#
# Исправим опечатку в колонке `Период`

# %%
██████['Период'].unique()
# Out:
# array(['текущий_месяц', 'предыдцщий_месяц'], dtype=object)

# %%
██████['Период'] = ██████['Период'].replace('предыдцщий_месяц', 'предыдущий_месяц')

██████.columns = ██████.columns.str.lower()

# %% [markdown]
# ### `██████`
#
# Переводим в нижний регистр колонки

# %%
██████.columns = ██████.columns.str.lower()

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных

# %% [markdown]
# ### Описательная статистика

# %%
for i in [██████, ██████, ██████, ██████]:
    display(i.describe(include = "all"))
    print('_____________________________________________')
    print('_____________________________________________')
# Out:
#                    id покупательская_активность тип_сервиса  \
# count     1300.000000                      1300        1300
# unique            NaN                         2           2
# top               NaN           Прежний уровень    стандарт
# freq              NaN                       802         924
# mean    215997.500000                       NaN         NaN
# std        375.421985                       NaN         NaN
# min     215348.000000                       NaN         NaN
# 25%     215672.750000                       NaN         NaN
# 50%     215997.500000                       NaN         NaN
# 75%     216322.250000                       NaN         NaN
# max     216647.000000                       NaN         NaN
#
#        разрешить_сообщать  маркет_актив_6_мес  маркет_актив_тек_мес  \
# count                1300         1300.000000           1300.000000
# unique                  2                 NaN                   NaN
# ...

# %% [markdown]
# #### Вывод
# Видим, что очень большое значение у максимума выручки в `██████`. Посмотрим на него ближе, когда будем строить графики. В остальном ничего настораживающего.

# %% [markdown]
# ### Строим графики

# %% [markdown]
# #### `██████`
# ##### Графики
# Сначала отберем покупателей, у которых покупательская активность была не менее трех месяцев.

# %%
# удалим выброс, который мы увидели на этапе проверки данных
# и те строки, где есть хотя бы один месяц с нулевой активностью

██████ = ██████.query('0 < выручка < 100000')

# %%
# создаем сводную таблицу
market_shop = (██████
               .pivot_table(index='id', columns='период', values='выручка')
               .dropna()
               .reset_index()
              )
market_shop.head()
# Out:
# период      id  предыдущий_месяц  препредыдущий_месяц  текущий_месяц
# 0       215349            5216.0               4472.0         4971.6
# 1       215350            5457.5               4826.0         5058.4
# 2       215351            6158.0               4793.0         6610.4
# 3       215352            5807.5               4594.0         5872.5
# 4       215353            4738.5               5124.0         5388.5

# %%
#строим графики

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(16,9))
axes[0].boxplot(market_shop['препредыдущий_месяц'])
axes[0].set_title('Размах в препред. мес.', fontsize=18, fontweight='bold')
axes[0].set_ylabel('Выручка', fontsize=14);

axes[1].boxplot(market_shop['предыдущий_месяц'])
axes[1].set_title('Размах в пред. мес.', fontsize=18, fontweight='bold')

axes[2].boxplot(market_shop['текущий_месяц'])
axes[2].set_title('Размах в текущем мес.', fontsize=18, fontweight='bold');

# %%
plt.figure(figsize=(14, 8))
sns.set_theme(style="whitegrid")

sns.kdeplot(market_shop['текущий_месяц'], label='текущий_месяц', linewidth=3)
sns.kdeplot(market_shop['предыдущий_месяц'], label='предыдущий_месяц', linewidth=3)
sns.kdeplot(market_shop['препредыдущий_месяц'], label='препредыдущий_месяц', linewidth=3)

plt.title('Распределение выручки за последние 3 месяца', fontsize=24, fontweight='bold')
plt.xlabel('Выручка', fontsize=18, fontweight='bold')
plt.ylabel('Плотность', fontsize=18, fontweight='bold')
plt.legend(title="Месяц", title_fontsize=16, fontsize=14, loc='upper right',
           frameon=True, shadow=True, facecolor='white')
plt.grid(True, linestyle='--', alpha=0.7)

plt.show()

# %%
print('Выручка в препредыдущем месяце:', market_shop['препредыдущий_месяц'].sum())
print('Выручка в предыдущем месяце:', market_shop['предыдущий_месяц'].sum())
print('Выручка в текущем месяце:', market_shop['текущий_месяц'].sum())
# Out:
# Выручка в препредыдущем месяце: 6267718.0
# Выручка в предыдущем месяце: 6411919.5
# Выручка в текущем месяце: 6788572.5

# %% [markdown]
# ##### Выводы
#
# 1. Оставили только тех, у кого была покупательская активность не менее трёх месяцев.
# 2. Удалили выброс, который перекашивал данные.
# 3. Видим, что разброс и распределение выручки растет с каждым месяцем – магазин наращивает продажи.

# %% [markdown]
# #### `██████`
# ##### Категориальные признаки

# %%
#здесь и далее оставляем только тех клиентов, которые есть в обновленном датасете market_shop

██████ = ██████[██████['id'].isin(market_shop['id'])]

# %%
sns.set_theme(style="whitegrid")
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(24, 8))

# Покупательская активность
axes[0].pie(██████['покупательская_активность'].value_counts(),
            labels=market_file['покупательская_активность'].value_counts().index,
            autopct='%1.1f%%',
            colors=['#4C72B0', '#55A868'],
            wedgeprops={'edgecolor': 'black', 'linewidth': 1.5},
            textprops={'fontsize': 20});
axes[0].set_title('Покупательская активность', fontsize=24, fontweight='bold')

# Тип сервиса
axes[1].pie(██████['тип_сервиса'].value_counts(),
            labels=market_file['тип_сервиса'].value_counts().index,
            autopct='%1.1f%%',
            colors=['#C44E52', '#8172B2'],
            wedgeprops={'edgecolor': 'black', 'linewidth': 1.5},
            textprops={'fontsize': 20});
axes[1].set_title('Тип сервиса', fontsize=24, fontweight='bold')

# Оповещения
axes[2].pie(██████['разрешить_сообщать'].value_counts(),
            labels=market_file['разрешить_сообщать'].value_counts().index,
            autopct='%1.1f%%',
            colors=['#CCB974', '#64A2C1'],
            wedgeprops={'edgecolor': 'black', 'linewidth': 1.5},
            textprops={'fontsize': 20});
axes[2].set_title('Оповещения', fontsize=24, fontweight='bold')

plt.tight_layout()
plt.show()

# Bar plot for "Популярная категория"
plt.figure(figsize=(14, 8))
██████['популярная_категория'].value_counts().sort_values().plot(kind='barh', color="#4C72B0")
plt.title('Популярные категории', fontsize=24, fontweight='bold', color="#333333")
plt.xlabel('Частота', fontsize=18, fontweight='bold')
plt.ylabel('Категории', fontsize=18, fontweight='bold')
plt.grid(True, linestyle='--', alpha=0.7)
sns.despine()
plt.show()

# %% [markdown]
# ##### Количественные признаки

# %%
plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")

sns.countplot(██████['маркет_актив_тек_мес'], palette="coolwarm", linewidth=1.5, edgecolor='black')
plt.title('Распределение маркетинговой активности в текущем месяце', fontsize=24, fontweight='bold', color="#333333")
plt.xlabel('Количество маркетинговых активностей', fontsize=18, fontweight='bold')
plt.ylabel('Частота', fontsize=18, fontweight='bold')

plt.grid(True, linestyle='--', alpha=0.7)
sns.despine()

plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 8))
sns.set_theme(style="whitegrid")

# Боксплот
sns.boxplot(y=██████['длительность'], ax=axes[0], color='#4C72B0', width=0.5, linewidth=2)
axes[0].set_title('Размах длительности регистрации', fontsize=20, fontweight='bold', color="#333333")
axes[0].set_ylabel('Дней зарегистрирован', fontsize=16, fontweight='bold')
axes[0].grid(True, linestyle='--', alpha=0.7)
sns.despine(ax=axes[0])

# Гистограмма
sns.histplot(██████['длительность'], bins=50, ax=axes[1], color='#55A868', kde=True, alpha=0.8, edgecolor='black')
axes[1].set_title('Распределение длительности регистрации', fontsize=20, fontweight='bold', color="#333333")
axes[1].set_xlabel('Дней зарегистрирован', fontsize=16, fontweight='bold')

mean_val = ██████['длительность'].mean()
median_val = ██████['длительность'].median()
axes[1].axvline(x=mean_val, color='red', linestyle='--', linewidth=2, label=f'Среднее: {mean_val:.1f}')
axes[1].axvline(x=median_val, color='green', linestyle='--', linewidth=2, label=f'Медиана: {median_val:.1f}')

axes[1].legend(fontsize=14, frameon=True, shadow=True, facecolor='white', loc='upper right')

axes[1].grid(True, linestyle='--', alpha=0.7)
sns.despine(ax=axes[1])

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 8))
sns.set_theme(style="whitegrid")

# Боксплот
sns.boxplot(y=██████['акционные_покупки'], ax=axes[0], color='#4C72B0', width=0.5, linewidth=2)
axes[0].set_title('Размах доли акционных покупок', fontsize=20, fontweight='bold', color="#333333")
axes[0].set_ylabel('Доля акционных покупок', fontsize=16, fontweight='bold')
axes[0].grid(True, linestyle='--', alpha=0.7)
sns.despine(ax=axes[0])

# Гистограмма
sns.histplot(██████['акционные_покупки'], bins=50, ax=axes[1], color='#55A868', kde=True, alpha=0.8, edgecolor='black')
axes[1].set_title('Распределение доли акционных покупок', fontsize=20, fontweight='bold', color="#333333")
axes[1].set_xlabel('Доля акционных покупок', fontsize=16, fontweight='bold')

mean_val = ██████['акционные_покупки'].mean()
median_val = ██████['акционные_покупки'].median()
axes[1].axvline(x=mean_val, color='red', linestyle='--', linewidth=2, label=f'Среднее: {mean_val:.1f}')
axes[1].axvline(x=median_val, color='green', linestyle='--', linewidth=2, label=f'Медиана: {median_val:.1f}')

axes[1].legend(fontsize=14, frameon=True, shadow=True, facecolor='white', loc='upper right')

axes[1].grid(True, linestyle='--', alpha=0.7)
sns.despine(ax=axes[1])

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")

sns.countplot(██████['средний_просмотр_категорий_за_визит'], palette="coolwarm", linewidth=1.5, edgecolor='black')
plt.title('Распределение просмотра категорий за визит', fontsize=24, fontweight='bold', color="#333333")
plt.xlabel('Количество категорий', fontsize=18, fontweight='bold')
plt.ylabel('Частота', fontsize=18, fontweight='bold')

plt.grid(True, linestyle='--', alpha=0.7)
sns.despine()

plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")

sns.countplot(██████['неоплаченные_продукты_штук_квартал'], palette="coolwarm", linewidth=1.5, edgecolor='black')
plt.title('Распределение неоплаченных продуктов', fontsize=24, fontweight='bold', color="#333333")
plt.xlabel('Количество продуктов', fontsize=18, fontweight='bold')
plt.ylabel('Частота', fontsize=18, fontweight='bold')

plt.grid(True, linestyle='--', alpha=0.7)
sns.despine()

plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")

sns.countplot(██████['ошибка_сервиса'], palette="coolwarm", linewidth=1.5, edgecolor='black')
plt.title('Распределение ошибок сервиса', fontsize=24, fontweight='bold', color="#333333")
plt.xlabel('Количество ошибок', fontsize=18, fontweight='bold')
plt.ylabel('Частота', fontsize=18, fontweight='bold')

plt.grid(True, linestyle='--', alpha=0.7)
sns.despine()

plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")

sns.countplot(██████['страниц_за_визит'], palette="coolwarm", linewidth=1.5, edgecolor='black')
plt.title('Распределение страниц за визит', fontsize=24, fontweight='bold', color="#333333")
plt.xlabel('Количество страниц', fontsize=18, fontweight='bold')
plt.ylabel('Частота', fontsize=18, fontweight='bold')

plt.grid(True, linestyle='--', alpha=0.7)
sns.despine()

plt.show()

# %% [markdown]
# ##### Выводы
#
# 1. Покупательская активность снизилась почти у 38% клиентов.\
#     *Это наш целевой признак, поэтому отметим заранее, что есть дисбаланс классов.*
# 2. Около 30% пользователей имеют премиум-подписку.
# 3. 3 из 4 клиентов разрешают присылать дополнительные предложения.
# 4. Самые популярные категории товаров – для детей, домашний текстиль и косметика.
# 5. В среднем пользователи получают по 4 доп. предложения в месяц.
# 6. В среднем пользователи зарегистрированы в магазине 600 дней.
# 7. Примерно треть товаров от всей корзины покупается по акции, но есть и те, у кого эта доля составляет больше 80%.
# 8. В среднем пользователи просматривают по 3 категории за визит.
# 9. В среднем в корзинах лежит от 2 до 4 неоплаченных продуктов.
# 10. На каждого пользователя приходится примерно по 4 ошибки сервиса.
# 11. Пользователи просматривают примерно 8 страниц за визит.
#
# Немного выбросов в некоторых признаках есть, но удалять мы их не будем, так как они могут относиться к малочисленным сегментам пользователей – со сниженной активностью, премиум-подпиской и т.д.

# %% [markdown]
# #### `██████`
# ##### Графики

# %%
market_minutes = ██████.pivot_table(index='id', columns='период', values='минут').reset_index()
market_minutes = market_minutes[market_minutes['id'].isin(market_shop['id'])]

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,10))
sns.set_theme(style="whitegrid")

# KDE
sns.kdeplot(market_minutes['предыдущий_месяц'], label='Предыдущий месяц', color="#4C72B0", ax=axes[0], linewidth=3, alpha=0.7)
sns.kdeplot(market_minutes['текущий_месяц'], label='Текущий месяц', color="#55A868", ax=axes[0], linewidth=3, alpha=0.7)

axes[0].set_title('Распределение длительности сессий', fontsize=30, fontweight='bold', color="#333333")
axes[0].set_xlabel('Минуты', fontsize=20, fontweight='bold')
axes[0].set_ylabel('Плотность', fontsize=20, fontweight='bold')
axes[0].legend(title="Период", title_fontsize=18, fontsize=16, frameon=True, shadow=True, facecolor='white', loc='upper right')
axes[0].grid(True, linestyle='--', alpha=0.7)
sns.despine(ax=axes[0])

# Боксплот
axes[1].boxplot(market_minutes.loc[:, market_minutes.columns != 'id'].values, 
                labels=['Предыдущий месяц', 'Текущий месяц'],
                patch_artist=True, 
                boxprops=dict(facecolor="#4C72B0", color="black", linewidth=1.5), 
                medianprops=dict(color="black", linewidth=2),
                whiskerprops=dict(color="black", linewidth=1.5),
                capprops=dict(color="black", linewidth=1.5),
                flierprops=dict(marker='o', color='#55A868', markersize=6, alpha=0.5))

axes[1].set_title('Размах длительности сессий', fontsize=30, fontweight='bold', color="#333333")
axes[1].set_ylabel('Минуты', fontsize=20, fontweight='bold')
axes[1].grid(True, linestyle='--', alpha=0.7)
sns.despine(ax=axes[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Выводы
#
# В прошлом месяце в среднем длительность сессий была чуть дольше

# %% [markdown]
# #### `money`
#
# ##### Графики

# %%
money = money[money['id'].isin(market_shop['id'])]

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
sns.set_theme(style="whitegrid")

# Боксплот
sns.boxplot(y=money['прибыль'], ax=axes[0], color='#4C72B0', width=0.5, linewidth=2)
axes[0].set_title('Размах среднемесячной прибыли', fontsize=30, fontweight='bold', color="#333333")
axes[0].set_ylabel('Прибыль', fontsize=20)
axes[0].grid(True, linestyle='--', alpha=0.7)
sns.despine(ax=axes[0])

# Гистограмма
sns.histplot(money['прибыль'], bins=50, ax=axes[1], color='#55A868', kde=True, alpha=0.8, edgecolor='black')
axes[1].set_title('Распределение среднемесячной прибыли', fontsize=30, fontweight='bold', color="#333333")
axes[1].set_xlabel('Прибыль', fontsize=20)
axes[1].set_ylabel('Частота', fontsize=20)

mean_val = money['прибыль'].mean()
median_val = money['прибыль'].median()
axes[1].axvline(x=mean_val, color='red', linestyle='--', linewidth=2, label=f'Среднее: {mean_val:.1f}')
axes[1].axvline(x=median_val, color='green', linestyle='--', linewidth=2, label=f'Медиана: {median_val:.1f}')

axes[1].legend(fontsize=16, frameon=True, shadow=True, facecolor='white', loc='upper right')

axes[1].grid(True, linestyle='--', alpha=0.7)
sns.despine(ax=axes[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Выводы
#
# Из условий неизвестно, в чем измеряется прибыль, но предположим, что в тыс. рублей. В таком случае, в среднем пользователь приносит магазину чуть больше 4000 рублей в месяц.

# %% [markdown]
# ## Шаг 4. Объединение таблиц

# %%
data = market_file.merge(market_shop, on='id', how='left')
data.head(3)
# Out:
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215349                 Снизилась     премиум                 да
# 1  215350                 Снизилась    стандарт                нет
# 2  215351                 Снизилась    стандарт                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 4.4                     4           819               0.75
# 1                 4.9                     3           539               0.14
# 2                 3.2                     5           896               0.99
#
#   популярная_категория  средний_просмотр_категорий_за_визит  \
# 0     Товары для детей                                    4
# 1    Домашний текстиль                                    5
# 2     Товары для детей                                    5
#
#    неоплаченные_продукты_штук_квартал  ошибка_сервиса  страниц_за_визит  \
# ...

# %%
data = data.rename(columns={'предыдущий_месяц': 'выручка_пред',
                    'препредыдущий_месяц': 'выручка_препред',
                    'текущий_месяц': 'выручка_текущ'})
data.head(3)
# Out:
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215349                 Снизилась     премиум                 да
# 1  215350                 Снизилась    стандарт                нет
# 2  215351                 Снизилась    стандарт                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 4.4                     4           819               0.75
# 1                 4.9                     3           539               0.14
# 2                 3.2                     5           896               0.99
#
#   популярная_категория  средний_просмотр_категорий_за_визит  \
# 0     Товары для детей                                    4
# 1    Домашний текстиль                                    5
# 2     Товары для детей                                    5
#
#    неоплаченные_продукты_штук_квартал  ошибка_сервиса  страниц_за_визит  \
# ...

# %%
data = data.merge(market_minutes, on='id', how='left')
data = data.rename(columns={'предыдущий_месяц': 'минуты_пред',
                    'текущий_месяц': 'минуты_текущ'})

# %%
data_main_info(data)
# Out:
# -------------------------------------------------------------------------------
# Первые 3 строки:
# -------------------------------------------------------------------------------
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215349                 Снизилась     премиум                 да
# 1  215350                 Снизилась    стандарт                нет
# 2  215351                 Снизилась    стандарт                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 4.4                     4           819               0.75
# 1                 4.9                     3           539               0.14
# 2                 3.2                     5           896               0.99
#
#   популярная_категория  средний_просмотр_категорий_за_визит  \
# 0     Товары для детей                                    4
# 1    Домашний текстиль                                    5
# ...

# %% [markdown]
# ## Шаг 5. Корреляционный анализ
#
# ### Построение матрицы phik

# %%
interval_cols = ['маркет_актив_6_мес', 'акционные_покупки', 'выручка_препред',
                 'выручка_пред', 'выручка_текущ', 'длительность']

plt.figure(figsize=(12, 8));
plt.grid(False)
mask = np.triu(np.ones_like(data.loc[:, 'покупательская_активность':].phik_matrix(interval_cols = interval_cols), dtype=bool));
sns.heatmap(data.loc[:, 'покупательская_активность':].phik_matrix(interval_cols = interval_cols),
            annot=True, fmt='.2f', mask=mask, cmap='Spectral', linewidths=0.5);

# %% [markdown]
# ### Вывод
#
# 1. О мультиколлинеарности здесь говорить не приходится, потому что нет значений от 0.9 и выше.
# 2. Но три признака не показали связи с целевым: `разрешить_сообщать` и `маркет_актив_тек_мес` – можно их удалить.

# %%
#удаляем признаки
data = data.drop(['разрешить_сообщать', 'маркет_актив_тек_мес'], axis=1)

# %% [markdown]
# ## Шаг 6. Использование пайплайнов

# %% [markdown]
# ### Создание пайплайнов

# %%
# Оптимизация числовых типов данных
def optimize_memory_usage(df: pd.DataFrame, print_size: bool=True) -> pd.DataFrame:
    '''
    Function optimizes memory usage in dataframe
    df: pd.DataFrame - data table
    print_size: bool - display of optimization results
    return pd.DataFrame - amount of optimized memory
    '''
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64'] # Типы, которые будем проверять на оптимизацию
    # Размер занимаемой памяти до оптимизации (в Мб)
    before_size = df.memory_usage().sum() / 1024**2    
    for column in df.columns:
        column_type = df[column].dtypes
        if column_type in numerics:
            column_min = df[column].min()
            column_max = df[column].max()
            if str(column_type).startswith('int'):
                if column_min > np.iinfo(np.int8).min and column_max < np.iinfo(np.int8).max:
                    df[column] = df[column].astype(np.int8)
                elif column_min > np.iinfo(np.int16).min and column_max < np.iinfo(np.int16).max:
                    df[column] = df[column].astype(np.int16)
                elif column_min > np.iinfo(np.int32).min and column_max < np.iinfo(np.int32).max:
                    df[column] = df[column].astype(np.int32)
                elif column_min > np.iinfo(np.int64).min and column_max < np.iinfo(np.int64).max:
                    df[column] = df[column].astype(np.int64)  
            else:
                if column_min > np.finfo(np.float32).min and column_max < np.finfo(np.float32).max:
                    df[column] = df[column].astype(np.float32)
                else:
                    df[column] = df[column].astype(np.float64)    
    # Размер занимаемой памяти после оптимизации (в Мб)
    after_size = df.memory_usage().sum() / 1024**2
    if print_size: print('Размер использования памяти: до {:5.2f} Mb - после {:5.2f} Mb ({:.1f}%)'
                         .format(before_size, after_size, 100 * (before_size - after_size) / before_size))
    return df

# %%
data = optimize_memory_usage(data)
# Out:
# Размер использования памяти: до  0.17 Mb - после  0.08 Mb (52.9%)

# %%
# делим данные на тренировочную и тестовую выборки
X = data.drop(['id','покупательская_активность'], axis=1)
y = data['покупательская_активность']

X_train, X_test, y_train, y_test = (
    train_test_split(X, y,                                              
    test_size = TEST_SIZE,
    random_state = RANDOM_STATE,
    stratify=y)
)

# кодируем целевой признак в тренировочной и тестовой выборках
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test)

# %%
# проверяем размеры выборок
display(X_train.shape)
display(y_train.shape)

display(X_test.shape)
display(y_test.shape)
# Out:
# (972, 14)
# (972,)
# (324, 14)
# (324,)

# %%
# создаём списки с названиями признаков
ohe_columns = ['популярная_категория']
ord_columns = ['тип_сервиса']
num_columns = ['маркет_актив_6_мес',
               'акционные_покупки',
               'средний_просмотр_категорий_за_визит',
              'неоплаченные_продукты_штук_квартал',
              'ошибка_сервиса',
              'страниц_за_визит',
              'выручка_пред',
              'выручка_препред',
              'выручка_текущ',
              'минуты_пред',
              'минуты_текущ',
              'длительность']

# %%
# создаём пайплайн для подготовки признаков из списка ohe_columns: заполнение пропусков и OHE-кодирование
# SimpleImputer + OHE
ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))
    ]
    )

# %%
# создаём пайплайн для подготовки признаков из списка ord_columns: заполнение пропусков и Ordinal-кодирование
# SimpleImputer + OE
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord', OrdinalEncoder(
         categories=[['стандарт', 'премиум']],
         handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# %%
# создаём общий пайплайн для подготовки данных
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %%
# создаём итоговый пайплайн: подготовка данных и модель
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

# %%
param_grid = [
    
        # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 10),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },
    
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 14),
        'models__max_features': (1,5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear', 
            penalty='l1'
        )],
        'models__C': range(1, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели SVC()
    {
        'models': [SVC(random_state=RANDOM_STATE,
                       probability=True
                      )],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  

    },
]

# %% [markdown]
# В качестве метрики для оценки выберем ROC-AUC, потому что ее можно использовать в случае, когда объектов с одним значением целевого признака больше, чем с другими (а у нас дисбаланс классов).

# %%
randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring='roc_auc',
    random_state=RANDOM_STATE,
    n_jobs=-1
)

# %%
randomized_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('ohe',
#                                                                                Pipeline(steps=[('simpleImputer_ohe',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('ohe',
#                                                                                                 OneHotEncoder(drop='first',
#                                                                                                               handle_unknown='ignore',
# ...

# %%
result = pd.DataFrame(randomized_search.cv_results_)
display(result[
    ['rank_test_score', 'param_models', 'mean_test_score','params']
].sort_values('rank_test_score'))
# Out:
#    rank_test_score                                       param_models  \
# 8                1  LogisticRegression(penalty='l1', random_state=...
# 1                2                             KNeighborsClassifier()
# 2                3                             KNeighborsClassifier()
# 7                4            DecisionTreeClassifier(random_state=42)
# 4                5            DecisionTreeClassifier(random_state=42)
# 5                6            DecisionTreeClassifier(random_state=42)
# 0                7            DecisionTreeClassifier(random_state=42)
# 6                8            DecisionTreeClassifier(random_state=42)
# 3                9            DecisionTreeClassifier(random_state=42)
# 9               10                             KNeighborsClassifier()
#
#    mean_test_score                                             params
# 8         0.898983  {'preprocessor__num': StandardScaler(), 'model...
# ...

# %%
print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print ('\n\nМетрика лучшей модели на кросс-валидации:', randomized_search.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['популярная_категория']),
#                                                  ('ord',
# ...

# %%
probas = randomized_search.predict_proba(X_test)[:, 1]
print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test, probas)}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.9176070865186264

# %%
model = DummyClassifier()

model.fit(X_train, y_train)
probas = model.predict_proba(X_test)[:, 1]
print(f'Метрика ROC-AUC константной модели: {roc_auc_score(y_test, probas)}')
# Out:
# Метрика ROC-AUC константной модели: 0.5

# %% [markdown]
# ### Вывод
# Лучшая модель – LogisticRegression с параметрами `C=1, penalty='l1', random_state=42, solver='liblinear'` и масштабированием `StandardScaler()`\
# Roc-auc на тренировочной выборке – 0.89, на тренировочной – 0.91.

# %% [markdown]
# ## Шаг 7. Анализ важности признаков

# %%
# лучшая модель
best_model = randomized_search.best_estimator_.named_steps['models']

# лучшая предобработка
preprocessor = randomized_search.best_estimator_.named_steps['preprocessor']

# коэффициенты модели
coefficients = randomized_search.best_estimator_['models'].coef_[0]

# %%
X_train_preprocessed = preprocessor.transform(X_train)
X_test_preprocessed = preprocessor.transform(X_test)

ohe_feature_names = preprocessor.named_transformers_['ohe'].get_feature_names_out(input_features=ohe_columns)
ord_feature_names = preprocessor.named_transformers_['ord'].get_feature_names_out(input_features=ord_columns)
all_feature_names = np.concatenate([ohe_feature_names, ord_feature_names, num_columns])
X_train_preprocessed = pd.DataFrame(X_train_preprocessed, columns=all_feature_names)
X_test_preprocessed = pd.DataFrame(X_test_preprocessed, columns=all_feature_names)

# %%
explainer = shap.LinearExplainer(best_model, X_test_preprocessed)
shap_values = explainer(X_test_preprocessed)

# %%
fig, ax = plt.gcf(), plt.gca()
ax.set_title('\nЗначимость признаков лучшей модели\n', fontsize=20, fontweight='bold')
ax.set_ylabel("Признаки", fontsize=14)
ax.set_xlabel("SHAP-значение (влияние на модель)", fontsize=14)
shap.plots.beeswarm(shap_values, max_display = 30)

# %% [markdown]
# ### Выводы
#
# 1. Менее всего для модели значимы признаки категорий с детскими товарами, кухонной посудой, косметикой и аксессуарами, а также типом сервиса.
# 2. Сильнее всего на целевой признак влияют страницы за визит, категории за визит и время на сайте  (чем больше признак, тем меньше вероятность снижения активности). Также важны акционные покупки (кто заходит только за акционными товарами, у того активность низкая) и товары в корзине (если их много, то они скорее всего дожидаются скидки). Фактор маркетинговой активности так же важен (больше предложений – больше активности).
#
# ###### Как это может использовать бизнес?
# Чтобы удерживать покупательскую активность, нужно для рисковых клиентов увеличить количество маркетинговых взаимодействий.

# %% [markdown]
# ### Шаг 8. Сегментация покупателей
#
# Выделим сегмент клиентов с высокой вероятностью снижения покупательской активности и наиболее высокой прибыльностью. Клиентами с высокой прибыльностью будут считаться те, кто тратит больше 4.7 тыс. рублей в месяц (в среднем клиенты тратят от 3 до 4.7).

# %%
# сделаем столбец с вероятностями в общем датасете
data_prob = preprocessor.transform(X)
probs = best_model.predict_proba(data_prob)[:, 1]
predictions = best_model.predict(data_prob)
data['probs'] = probs

#добавим к этим наблюдениям данные по выручке
data = data.merge(money, on='id', how='left')

data['прибыльность'] = data['прибыль'].apply(lambda прибыль: True if прибыль > 4.7 else False)

# %% [markdown]
# Выделим признаки, которые показали наибольшую важность для модели

# %%
numeral = ['минуты_пред', 'акционные_покупки', 'маркет_актив_6_мес']
discrete = ['страниц_за_визит','средний_просмотр_категорий_за_визит', 'неоплаченные_продукты_штук_квартал']

# %% [markdown]
# Сделаем порог более строгим, чтобы различия были более очевидны.

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(data = data[data['покупательская_активность'] == 'Прежний уровень'], x = 'probs', y = 'прибыль', color='#4CAF50')
sns.scatterplot(data = data[data['покупательская_активность'] == 'Снизилась'], x = 'probs', y = 'прибыль', color='#FF7043')
plt.axvline(0.63, linestyle='--', color='Blue')
plt.title('Деление покупателей на сегменты, р=0.63', fontsize=20, fontweight='bold')
plt.show()

# %% [markdown]
# ### Анализ количественных признаков

# %%
# Настройки общего стиля графиков
sns.set_theme(style="whitegrid")

# Построение KDE графиков для числовых признаков
for col in numeral:
    plt.figure(figsize=(12, 8))
    sns.kdeplot(data[data['probs'] < 0.63][col], 
                label='Остальные клиенты', 
                color="#4C72B0", 
                linewidth=2.5, 
                fill=True, 
                alpha=0.4)
    sns.kdeplot(data[(data['прибыльность'] == True) & (data['probs'] > 0.63)][col], 
                label='Прибыльные с риском снижения', 
                color="#55A868", 
                linewidth=2.5, 
                fill=True, 
                alpha=0.4)
    plt.axvline(x=data[data['probs'] < 0.63][col].mean(), color='red', linestyle='--', linewidth=2, label='Среднее (остальные)')
    plt.axvline(x=data[(data['прибыльность'] == True) & (data['probs'] > 0.63)][col].mean(), color='green', linestyle='--', linewidth=2, label='Среднее (прибыльные)')
    plt.title(f"Распределение признака: {col}", fontsize=22, fontweight='bold', color="#333333")
    plt.xlabel(col, fontsize=18)
    plt.ylabel('Плотность', fontsize=18)
    plt.legend(fontsize=14, title="Группы", title_fontsize=16, frameon=True, shadow=True, facecolor='white', loc='upper right')
    plt.grid(True, linestyle='--', alpha=0.6)
    sns.despine()
    plt.show()

# Построение countplot для дискретных признаков
for col in discrete:
    plt.figure(figsize=(12, 8))
    sns.countplot(data=data[(data['прибыльность'] == True) & (data['probs'] > 0.63)], x=col, color="#55A868", alpha=0.7, linewidth=1.5, edgecolor='black', label='Прибыльные с риском снижения')
    sns.countplot(data=data[data['probs'] < 0.63], x=col, color="#4C72B0", alpha=0.5, linewidth=1.5, edgecolor='black', label='Остальные клиенты')
    plt.axvline(x=data[data['probs'] < 0.63][col].median(), color='red', linestyle='--', linewidth=2, label='Медиана (остальные)')
    plt.axvline(x=data[(data['прибыльность'] == True) & (data['probs'] > 0.63)][col].median(), color='green', linestyle='--', linewidth=2, label='Медиана (прибыльные)')
    plt.title(f"Распределение признака: {col}", fontsize=22, fontweight='bold', color="#333333")
    plt.xlabel(col, fontsize=18)
    plt.ylabel('Количество', fontsize=18)
    plt.legend(fontsize=14, title="Группы", title_fontsize=16, frameon=True, shadow=True, facecolor='white', loc='upper right')
    plt.grid(True, linestyle='--', alpha=0.6)
    sns.despine()
    plt.show()

# %% [markdown]
# ### Анализ качественных признаков

# %%
fig, ax = plt.subplots(1, 2, figsize=(30, 12))
plt.subplots_adjust(wspace=0.4, bottom=0.2)

# Барплот для остальных клиентов
(data[data['probs'] < 0.63]['популярная_категория']
 .value_counts().sort_values()
 .plot(kind='barh', color='#4C72B0', ax=ax[0]))
ax[0].set_title('Популярные категории у остальных клиентов', fontsize=22, fontweight='bold', color="#333333")
ax[0].set_xlabel('Количество покупок в категории', fontsize=18)
ax[0].set_ylabel('Категории', fontsize=18)
ax[0].grid(True, linestyle='--', alpha=0.6)
sns.despine()

# Барплот для прибыльных клиентов с риском
(data[(data['прибыльность'] == True) & (data['probs'] > 0.63)]['популярная_категория']
 .value_counts().sort_values()
 .plot(kind='barh', color='#55A868', ax=ax[1]))
ax[1].set_title('Популярные категории у прибыльных клиентов с риском снижения', fontsize=22, fontweight='bold', color="#333333")
ax[1].set_xlabel('Количество покупок в категории', fontsize=18)
ax[1].set_ylabel('Категории', fontsize=18)
ax[1].grid(True, linestyle='--', alpha=0.6)
sns.despine()

plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(30, 12))
plt.subplots_adjust(wspace=0.4, bottom=0.2)

# Барплот для остальных клиентов
(data[data['probs'] < 0.63]['тип_сервиса']
 .value_counts().sort_values()
 .plot(kind='bar', color='#4C72B0', ax=ax[0]))
ax[0].set_title('Распределение типов сервиса у остальных клиентов', fontsize=22, fontweight='bold', color="#333333")
ax[0].set_xlabel('Тип сервиса', fontsize=18)
ax[0].set_ylabel('Количество подписок', fontsize=18)
ax[0].grid(True, linestyle='--', alpha=0.6)
sns.despine()

# Барплот для прибыльных клиентов с риском
(data[(data['прибыльность'] == True) & (data['probs'] > 0.63)]['тип_сервиса']
 .value_counts().sort_values()
 .plot(kind='bar', color='#55A868', ax=ax[1]))
ax[1].set_title('Распределение типов сервиса у прибыльных клиентов с риском снижения', fontsize=22, fontweight='bold', color="#333333")
ax[1].set_xlabel('Тип сервиса', fontsize=18)
ax[1].set_ylabel('Количество подписок', fontsize=18)
ax[1].grid(True, linestyle='--', alpha=0.6)
sns.despine()

plt.show()

# %% [markdown]
# ### Выводы
#
# Для дополнительного исследования мы взяли сегмент **клиентов с высокой вероятностью снижения покупательской активности и наиболее высокой прибыльностью** (траты больше 4.7 тыс. рублей в месяц и вероятность снижения 0.63).\
# \
# **Отличия этого сегмента от остальной массы клиентов**:
# - посещают меньше страниц за визит (в районе 6 при медиане в 12)
# - смотрят меньше категорий (3 против 5)
# - на треть меньше времени тратят на визит (10 минут против 15)
# - больше 40% товаров приобретают по акции, в то время как остальные – 20%
# - держат больше неоплаченных товаров в корзине (4 против 2)
# - получают чуть меньше маркетинговых взаимодействий
# - самая популярная категория у этого сегмента – косметика и аксессуары, наименее популярная – техника
# - доля премиум-подписок больше, чем у всей массы клиентов
#
# **Рекомендация**: увеличить маркетинговую активность, а также больше персонализировать предложения, уделяя внимание детским товарам, косметике и аксессуарам и домашнему текстилю. Также можно увеличить количество акций, поскольку этот сегмент интересуется скидками больше, чем остальная масса клиентов.

# %% [markdown]
# ## Шаг 9. Общий вывод
#
# ### Описание задачи
# Разработать решение для интернет-магазина "В один клик", которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.
#
# ### Описание исходных данных и проведённой предобработки
#
# ###### `██████.csv`
# Таблица, которая содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
# - Исправлены форматы (`Маркет_актив_6_мес` на `float`, `Акционные_покупки` на `float`)
# - Исправлена опечатка в в столбце `Тип сервиса`
# - Колонки оформлены змеиным_языком и переведены в нижний регистр
#
# ###### `██████.csv`
# Таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
# - Выручка переведена в числовое значение
#
# ###### `██████.csv`
# Таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
# - Исправлена опечатка в колонке `Период`
#
# ###### `██████.csv`
# Таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
# - Колонки переведены в нижний регистр
#
#
# При объединении данных в единую таблицу взяты только клиенты с покупательской активностью не менее трёх месяцев, то есть таких, которые что-либо покупали в этот период. Также удалены выбросы в прибыли.
#
# ### Что сделано для поиска лучшей модели
# 1. Предобработка данных: описана выше
# 2. Исследовательский анализ:
#     - Видим, что разброс и распределение выручки растет с каждым месяцем – магазин наращивает продажи.
#     - Покупательская активность снизилась почти у 38% клиентов. Выявлен дисбаланс классов.
#     - Около 30% пользователей имеют премиум-подписку.
#     - 3 из 4 клиентов разрешают присылать дополнительные предложения.
#     - Самые популярные категории товаров – для детей, домашний текстиль и косметика.
#     - В среднем пользователи получают по 4 доп. предложения в месяц.
#     - В среднем пользователи зарегистрированы в магазине 600 дней.
#     - Примерно треть товаров от всей корзины покупается по акции, но есть и те, у кого эта доля составляет больше 80%.
#     - В среднем пользователи просматривают по 3 категории за визит.
#     - В среднем в корзинах лежит от 2 до 4 неоплаченных продуктов.
#     - На каждого пользователя приходится примерно по 4 ошибки сервиса.
#     - Пользователи просматривают примерно 8 страниц за визит.
#     - В прошлом месяце в среднем длительность сессий была чуть дольше.
#     - Из условий неизвестно, в чем измеряется прибыль, но предположим, что в тыс. рублей. В таком случае, в среднем пользователь приносит магазину чуть больше 4000 рублей в месяц.
# 3. Корреляционный анализ:
#     - мультиколлинеарность не выявлена
#     - Два признака не показали связи с целевым: `разрешить_сообщать` и `маркет_актив_тек_мес` – приняли решение удалить.
# 4.  Использование пайплайнов: перебрали несколько способов масштабирования, а также несколько моделей и гиперпараметров для них, и выбрали лучшую с помощью grid_search.
# ### Лучшая модель
# Лучшая модель – LogisticRegression с параметрами `C=1, penalty='l1', random_state=42, solver='liblinear'` и масштабированием `StandardScaler()`\
# Roc-auc на тренировочной выборке – 0.89, на тренировочной – 0.91.
#
# ### Выводы и дополнительные предложения для сегмента покупателей
# Для **клиентов с высокой вероятностью снижения покупательской активности и наиболее высокой прибыльностью** (траты больше 4.7 тыс. рублей в месяц и вероятность снижения 0.63) рекомендовано увеличить маркетинговую активность, а также больше персонализировать предложения, уделяя внимание детским товарам, косметике и аксессуарам и домашнему текстилю. Также можно увеличить количество акций, поскольку этот сегмент интересуется скидками больше, чем остальная масса клиентов.
