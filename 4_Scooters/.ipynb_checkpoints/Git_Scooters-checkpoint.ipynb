# %% [markdown]
# # Анализ сервиса аренды самокатов ██████

# %% [markdown]
# ### Описание задачи
#
# Сервис аренды самокатов ██████ передал данные о некоторых пользователях из нескольких городов, а также об их поездках. Нужно проанализировать гипотезы, которые помогут бизнесу вырасти:
# 1. Важно понять, тратят ли пользователи с подпиской больше времени на поездки? Если да, то пользователи с подпиской могут быть «выгоднее» для компании.
# 2. Расстояние одной поездки в 3130 метров — оптимальное с точки зрения износа самоката. Можно ли сказать, что среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает 3130 метров?
# 3. Будет ли помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки?
# 4. Представим ситуацию: техническая команда сервиса обновила сервера, с которыми взаимодействует мобильное приложение. Она надеется, что из-за этого количество обращений в техподдержку значимо снизилось. Некоторый файл содержит для каждого пользователя данные о количестве обращений до обновления и после него. Какой тест понадобился бы для проверки этой гипотезы?
#
# И дополнительно:
# 5. Отделу маркетинга ██████ поставили задачу: нужно провести акцию с раздачей промокодов на один бесплатный месяц подписки, в рамках которой как минимум 100 существующих клиентов должны продлить эту подписку. То есть по завершении периода действия подписки пользователь может либо отказаться от неё, либо продлить, совершив соответствующий платёж. Эта акция уже проводилась ранее и по итогу выяснилось, что после бесплатного пробного периода подписку продлевают 10 % пользователей. Нужно выяснить, какое минимальное количество промокодов нужно разослать, чтобы вероятность не выполнить план была примерно 5 %.
# 6.  Отдел маркетинга рассылает клиентам push-уведомления в мобильном приложении. Клиенты могут открыть его или не открывать. Известно, что уведомления открывают около 40 % получивших клиентов. Отдел планирует разослать 1 млн уведомлений. С помощью аппроксимации нужно построить примерный график распределения и оценить вероятность того, что уведомление откроют не более 399,5 тыс. пользователей.
#
# ### Описание данных
# Чтобы совершать поездки по городу, пользователи сервиса ██████ пользуются мобильным приложением. Сервисом можно пользоваться:
# - без подписки
#     - абонентская плата отсутствует;
#     - стоимость одной минуты поездки — 8 рублей;
#     - стоимость старта (начала поездки) — 50 рублей;
#
# - с подпиской Ultra
#     - абонентская плата — 199 рублей в месяц;
#     - стоимость одной минуты поездки — 6 рублей;
#     - стоимость старта — бесплатно.
#
# В основных данных есть информация о пользователях, их поездках и подписках.
#
# ██████████████████████████████
#
# ### Этапы работы
# 1. Загрузка данных
# 2. Предобработка
# 3. Исследовательский анализ данных
# 4. Объединение данных
# 5. Посдчет выручки
# 6. Проверка основных гипотез
# 7. Проверка дополнительных гипотез
# 8. Выводы

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-задачи" data-toc-modified-id="Описание-задачи-1">Описание задачи</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-2">Описание данных</a></span></li><li><span><a href="#Этапы-работы" data-toc-modified-id="Этапы-работы-3">Этапы работы</a></span></li><li><span><a href="#Основные-вопросы-исследования-и-короткие-ответы" data-toc-modified-id="Основные-вопросы-исследования-и-короткие-ответы-4">Основные вопросы исследования и короткие ответы</a></span></li><li><span><a href="#Дополнительные-вопросы-исследования" data-toc-modified-id="Дополнительные-вопросы-исследования-5">Дополнительные вопросы исследования</a></span></li><li><span><a href="#Шаг-0.-Подключение-библиотек" data-toc-modified-id="Шаг-0.-Подключение-библиотек-6"><em>Шаг 0. Подключение библиотек</em></a></span></li><li><span><a href="#Шаг-1.-Загрузка-данных" data-toc-modified-id="Шаг-1.-Загрузка-данных-7">Шаг 1. Загрузка данных</a></span><ul class="toc-item"><li><span><a href="#1.1-Cчитываем-данные" data-toc-modified-id="1.1-Cчитываем-данные-7.1">1.1 Cчитываем данные</a></span></li><li><span><a href="#1.2-Выводим-информацию-о-датасетах-–-первые-строки-и-инфо" data-toc-modified-id="1.2-Выводим-информацию-о-датасетах-–-первые-строки-и-инфо-7.2">1.2 Выводим информацию о датасетах – первые строки и инфо</a></span></li></ul></li><li><span><a href="#Шаг-2.-Предобработка-данных" data-toc-modified-id="Шаг-2.-Предобработка-данных-8">Шаг 2. Предобработка данных</a></span></li><li><span><a href="#Шаг-3.-Исследовательский-анализ-данных" data-toc-modified-id="Шаг-3.-Исследовательский-анализ-данных-9">Шаг 3. Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#3.1-Частота-встречаемости-городов" data-toc-modified-id="3.1-Частота-встречаемости-городов-9.1">3.1 Частота встречаемости городов</a></span></li><li><span><a href="#3.2-Cоотношение-пользователей-с-подпиской-и-без-подписки" data-toc-modified-id="3.2-Cоотношение-пользователей-с-подпиской-и-без-подписки-9.2">3.2 Cоотношение пользователей с подпиской и без подписки</a></span></li><li><span><a href="#3.3-Возраст-пользователей" data-toc-modified-id="3.3-Возраст-пользователей-9.3">3.3 Возраст пользователей</a></span></li><li><span><a href="#3.4-Расстояние,-которое-пользователь-преодолел-за-одну-поездку" data-toc-modified-id="3.4-Расстояние,-которое-пользователь-преодолел-за-одну-поездку-9.4">3.4 Расстояние, которое пользователь преодолел за одну поездку</a></span></li><li><span><a href="#3.5-Продолжительность-поездок" data-toc-modified-id="3.5-Продолжительность-поездок-9.5">3.5 Продолжительность поездок</a></span></li></ul></li><li><span><a href="#Шаг-4.-Объединение-данных" data-toc-modified-id="Шаг-4.-Объединение-данных-10">Шаг 4. Объединение данных</a></span><ul class="toc-item"><li><span><a href="#4.1-Создаем-единый-датафрейм" data-toc-modified-id="4.1-Создаем-единый-датафрейм-10.1">4.1 Создаем единый датафрейм</a></span></li><li><span><a href="#4.2-Делим-пользователей-с-подпиской-и-без-на-разные-датафреймы" data-toc-modified-id="4.2-Делим-пользователей-с-подпиской-и-без-на-разные-датафреймы-10.2">4.2 Делим пользователей с подпиской и без на разные датафреймы</a></span></li><li><span><a href="#4.3--Визуализируем-информацию-о-расстоянии-и-времени-поездок-для-пользователей-обеих-категорий" data-toc-modified-id="4.3--Визуализируем-информацию-о-расстоянии-и-времени-поездок-для-пользователей-обеих-категорий-10.3">4.3  Визуализируем информацию о расстоянии и времени поездок для пользователей обеих категорий</a></span></li></ul></li><li><span><a href="#Шаг-5.-Подсчёт-выручки" data-toc-modified-id="Шаг-5.-Подсчёт-выручки-11">Шаг 5. Подсчёт выручки</a></span><ul class="toc-item"><li><span><a href="#5.1-Найдем-суммарное-расстояние,-количество-поездок-и-суммарное-время-для-каждого-пользователя-за-каждый-месяц." data-toc-modified-id="5.1-Найдем-суммарное-расстояние,-количество-поездок-и-суммарное-время-для-каждого-пользователя-за-каждый-месяц.-11.1">5.1 Найдем суммарное расстояние, количество поездок и суммарное время для каждого пользователя за каждый месяц.</a></span></li><li><span><a href="#5.2.-Добавим-столбец-с-помесячной-выручкой,-которую-принёс-каждый-пользователь" data-toc-modified-id="5.2.-Добавим-столбец-с-помесячной-выручкой,-которую-принёс-каждый-пользователь-11.2">5.2. Добавим столбец с помесячной выручкой, которую принёс каждый пользователь</a></span></li></ul></li><li><span><a href="#Шаг-6.-Проверка-гипотез" data-toc-modified-id="Шаг-6.-Проверка-гипотез-12">Шаг 6. Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#6.1-Tратят-ли-пользователи-с-подпиской-больше-времени-на-поездки?" data-toc-modified-id="6.1-Tратят-ли-пользователи-с-подпиской-больше-времени-на-поездки?-12.1">6.1 Tратят ли пользователи с подпиской больше времени на поездки?</a></span></li><li><span><a href="#6.2-Можно-ли-сказать,-что-среднее-расстояние,-которое-проезжают-пользователи-с-подпиской-за-одну-поездку,-не-превышает-3130-метров?" data-toc-modified-id="6.2-Можно-ли-сказать,-что-среднее-расстояние,-которое-проезжают-пользователи-с-подпиской-за-одну-поездку,-не-превышает-3130-метров?-12.2">6.2 Можно ли сказать, что среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает 3130 метров?</a></span></li><li><span><a href="#6.3-Будет-ли-помесячная-выручка-от-пользователей-с-подпиской-по-месяцам-выше,-чем-выручка-от-пользователей-без-подписки?" data-toc-modified-id="6.3-Будет-ли-помесячная-выручка-от-пользователей-с-подпиской-по-месяцам-выше,-чем-выручка-от-пользователей-без-подписки?-12.3">6.3 Будет ли помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки?</a></span></li><li><span><a href="#6.4-Представьте-такую-ситуацию:-техническая-команда-сервиса-обновила-сервера,-с-которыми-взаимодействует-мобильное-приложение.-Она-надеется,-что-из-за-этого-количество-обращений-в-техподдержку-значимо-снизилось.-Некоторый-файл-содержит-для-каждого-пользователя-данные-о-количестве-обращений-до-обновления-и-после-него.-Какой-тест-вам-понадобился-бы-для-проверки-этой-гипотезы?" data-toc-modified-id="6.4-Представьте-такую-ситуацию:-техническая-команда-сервиса-обновила-сервера,-с-которыми-взаимодействует-мобильное-приложение.-Она-надеется,-что-из-за-этого-количество-обращений-в-техподдержку-значимо-снизилось.-Некоторый-файл-содержит-для-каждого-пользователя-данные-о-количестве-обращений-до-обновления-и-после-него.-Какой-тест-вам-понадобился-бы-для-проверки-этой-гипотезы?-12.4">6.4 Представьте такую ситуацию: техническая команда сервиса обновила сервера, с которыми взаимодействует мобильное приложение. Она надеется, что из-за этого количество обращений в техподдержку значимо снизилось. Некоторый файл содержит для каждого пользователя данные о количестве обращений до обновления и после него. Какой тест вам понадобился бы для проверки этой гипотезы?</a></span></li></ul></li><li><span><a href="#Шаг-7.-Распределения" data-toc-modified-id="Шаг-7.-Распределения-13">Шаг 7. Распределения</a></span><ul class="toc-item"><li><span><a href="#7.1.-Определяем-количество-промокодов" data-toc-modified-id="7.1.-Определяем-количество-промокодов-13.1">7.1. Определяем количество промокодов</a></span></li><li><span><a href="#7.2-Прогнозируем-открытие-уведомлений" data-toc-modified-id="7.2-Прогнозируем-открытие-уведомлений-13.2">7.2 Прогнозируем открытие уведомлений</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-14">Выводы</a></span></li></ul></div>

# %% [markdown]
# ### Основные вопросы исследования и короткие ответы
# *Q1: Тратят ли пользователи с подпиской больше времени на поездки?* \
# A1: *Да*, пользователи с подпиской тратят значимо больше времени на поездки. \
# \
# *Q2: Расстояние одной поездки в 3130 метров — оптимальное с точки зрения износа самоката. Можно ли сказать, что среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает 3130 метров?* \
# A2: *Нет*, среднее расстояние одной поездки не угрожает износу самокатов. \
# \
# *Q3: Будет ли помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки?* \
# A3: *Да*, пользователи с подпиской выгоднее для бизнеса и с этой точки зрения, поэтому нужно увеличить продажи подписок.
#
# ### Дополнительные вопросы исследования
# *Q1: Какое минимальное количество промокодов нужно разослать, чтобы вероятность не выполнить план была примерно 5%?*\
# А1:1161 промокод\
# \
# *Q2: Какова вероятность того, что уведомление откроют не более 399,5 тыс. пользователей?*\
# А2: 15%

# %% [markdown]
# ### *Шаг 0. Подключение библиотек*

# %%
import pandas as pd
import numpy as np
import pandas as pd
from scipy import stats as st
from scipy.stats import binom
from math import sqrt
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Шаг 1. Загрузка данных

# %% [markdown]
# #### 1.1 Cчитываем данные

# %%
try:
    users_go = pd.read_csv('████████████', sep=',')
    rides_go = pd.read_csv('████████████', sep=',')
    subscriptions_go = pd.read_csv('████████████v', sep=',')
except:
    users_go = pd.read_csv('██████████████████', sep=',')
    rides_go = pd.read_csv('██████████████████', sep=',')
    subscriptions_go = pd.read_csv('██████████████████', sep=',')

# %% [markdown]
# #### 1.2 Выводим информацию о датасетах – первые строки и инфо
#
# Ниже видно, что пропусков в данных нет, но нужно поправить формат в колонке `date` у датасета с поездками.

# %%
display(██████.head(), ██████.info())
display(██████o.head(), ██████.info())
display(██████.head(), ██████.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 0 to 1564
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1565 non-null   int64
#  1   name               1565 non-null   object
#  2   age                1565 non-null   int64
#  3   city               1565 non-null   object
#  4   subscription_type  1565 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 61.3+ KB
#    user_id        name  age            city subscription_type
# 0        1        Кира   22          Тюмень             ultra
# 1        2   Станислав   31            Омск             ultra
# 2        3     Алексей   20          Москва             ultra
# 3        4  Константин   26  Ростов-на-Дону             ultra
# 4        5       Адель   28            Омск             ultra
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# ...

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %% [markdown]
# 2.1. Приведем столбец `date` к типу даты pandas.

# %%
██████['date']= pd.to_datetime(██████['date'])

# %% [markdown]
# 2.2. Создадим новый столбец с номером месяца на основе столбца `date`.

# %%
██████['month'] = (██████['date']).dt.month

# %% [markdown]
# 2.3. Проверим наличие пропущенных значений и дубликатов в датафреймах.

# %%
frames = [██████, ██████, ██████]

for i in frames:
    print('Пропущенные значения:', i.isna().sum(), 'Дубликаты:', i.duplicated().sum(), sep='\n')
    print()
# Out:
# Пропущенные значения:
# user_id              0
# name                 0
# age                  0
# city                 0
# subscription_type    0
# dtype: int64
# Дубликаты:
# 31
#
# Пропущенные значения:
# user_id     0
# distance    0
# duration    0
# date        0
# month       0
# dtype: int64
# Дубликаты:
# 0
#
# Пропущенные значения:
# subscription_type    0
# minute_price         0
# start_ride_price     0
# subscription_fee     0
# dtype: int64
# Дубликаты:
# 0

# %% [markdown]
# Видим, что есть дубликаты в датафрейме с пользователями. Избавимся от них:

# %%
██████ = ██████.drop_duplicates()

# %% [markdown]
# ### Шаг 3. Исследовательский анализ данных
#
# Визуализируем и опишем общую информацию о пользователях и поездках.

# %% [markdown]
# #### 3.1 Частота встречаемости городов
#
# На графике ниже видно, что больше всего пользователей сервиса в Пятигорске, на последнем месте — Москва.

# %%
city_counts = ██████['city'].value_counts()

plt.figure(figsize=(12, 6))
city_counts.plot(kind='bar', color='#4CAF50', edgecolor='black', alpha=0.9)

plt.title('Распределение пользователей по городам', fontsize=20, fontweight='bold')
plt.xlabel('Город', fontsize=16)
plt.ylabel('Количество пользователей', fontsize=16)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

for index, value in enumerate(city_counts):
    plt.text(index, value + 2, str(value), ha='center', fontsize=10, fontweight='bold')

plt.show()

# %% [markdown]
#  Вот как распределяются доли пользователей между городами:

# %%
(██████.groupby('city')['user_id'].count()/len(users_go)*100).round(2).sort_values(ascending=False)
# Out:
# city
# Пятигорск         14.28
# Екатеринбург      13.30
# Ростов-на-Дону    12.91
# Краснодар         12.58
# Сочи              12.32
# Омск              11.93
# Тюмень            11.73
# Москва            10.95
# Name: user_id, dtype: float64

# %% [markdown]
# #### 3.2 Cоотношение пользователей с подпиской и без подписки

# %%
subscription_counts = ██████['subscription_type'].value_counts()

plt.figure(figsize=(5, 5))
plt.pie(subscription_counts, 
        labels=subscription_counts.index, 
        autopct='%1.1f%%', 
        startangle=90, 
        colors=['#4CAF50', '#FF7043'], 
        wedgeprops={'edgecolor': 'black', 'linewidth': 1.2},
        textprops={'fontsize': 14})

plt.title('Соотношение пользователей с подпиской и без подписки', fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# Судя по пайчарту, соотношение с небольшим перевесом в сторону пользователей без подписки. Посмотрим, сохраняется ли это соотношение в разрезе городов.

# %%
city_subscription_counts = ██████.pivot_table(index='city', columns='subscription_type',
                                                  values='user_id', aggfunc='count')

city_subscription_counts.plot(kind='bar', stacked=True, figsize=(15, 8),
                              color=['#4CAF50', '#FF7043'], edgecolor='black', alpha=0.9)

plt.title('Пользователи с подпиской и без подписки по городам', fontsize=22, fontweight='bold')
plt.xlabel('Город', fontsize=18)
plt.ylabel('Количество пользователей', fontsize=18)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(title="Тип подписки", fontsize=14, title_fontsize=16)

plt.show()

# %% [markdown]
# Диаграмма ниже показывает, что везде кроме Москвы количество пользователей без подписки превышает тех, у кого она есть. \
# \
# Посмотрим, где разница между пользователями с подпиской и без самая большая.

# %%
city_subscription_counts['delta%'] = ((city_subscription_counts['free'] - city_subscription_counts['ultra'])/(city_subscription_counts['free'] \
                                                                  + city_subscription_counts['ultra']) * 100).round(2)
city_subscription_counts.sort_values(by='delta%', ascending=False)
# Out:
# subscription_type  free  ultra  delta%
# city
# Краснодар           112     81   16.06
# Пятигорск           125     94   14.16
# Ростов-на-Дону      109     89   10.10
# Екатеринбург        112     92    9.80
# Сочи                103     86    8.99
# Тюмень               98     82    8.89
# Омск                 92     91    0.55
# Москва               84     84    0.00

# %% [markdown]
# Рекордно отрываются Краснодар и Пятигорск.

# %% [markdown]
# #### 3.3 Возраст пользователей

# %%
plt.figure(figsize=(12, 6))
plt.hist(██████['age'], bins=10, color='#4CAF50', edgecolor='black', alpha=0.8)

# Настраиваем заголовок и подписи осей
plt.title('Распределение возраста пользователей', fontsize=18, fontweight='bold')
plt.xlabel('Возраст', fontsize=12)
plt.ylabel('Количество пользователей', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Добавляем линию среднего возраста
mean_age = ██████['age'].mean()
plt.axvline(mean_age, color='orange', linestyle='--', linewidth=2, label=f'Средний возраст: {mean_age:.1f}')

plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# Минимальный возраст пользователей сервиса - 12 лет, максимальный - 43 года. Чаще всего самокатами пользуются люди в возрасте от 22 до 28 лет.

# %% [markdown]
# #### 3.4 Расстояние, которое пользователь преодолел за одну поездку

# %%
plt.figure(figsize=(12, 6))
plt.hist(██████['distance'], bins=50, color='#4CAF50', edgecolor='black', alpha=0.8)

plt.title('Распределение расстояний поездок', fontsize=18, fontweight='bold')
plt.xlabel('Расстояние (метры)', fontsize=12)
plt.ylabel('Количество поездок', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

mean_distance = ██████['distance'].mean()
median_distance = ██████['distance'].median()

plt.axvline(mean_distance, color='orange', linestyle='--', linewidth=2, label=f'Среднее: {mean_distance:.1f} м')
plt.axvline(median_distance, color='blue', linestyle='--', linewidth=2, label=f'Медиана: {median_distance:.1f} м')

plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# Минимальная дальность поездки меньше метра. Вероятно, это связано с тем, что пользователь передумал пользоваться самокатом – по личным причинам или из-за поломки/низкого уровня заряда самоката.
#
# Медиана – 3133 метра, чаще всего поездки клиентов укладываются в диапазон от 2543 до 3776 м. Рекордная поездка – больше 7 км. Интересно, в каком городе?

# %%
display(██████.query('distance == distance.max()'))
██████.query('user_id == 1411')
# Out:
#        user_id     distance  duration       date  month
# 16309     1411  7211.007745       0.5 2021-04-15      4
#       user_id       name  age       city subscription_type
# 1410     1411  Александр   20  Пятигорск              free

# %% [markdown]
# Однажды двадцатилетний Александр проехал по Пятигорску 7 км без подписки.

# %% [markdown]
# #### 3.5 Продолжительность поездок

# %%
plt.figure(figsize=(12, 6))
plt.hist(██████['duration'], bins=50, color='#4CAF50', edgecolor='black', alpha=0.8)

plt.title('Распределение продолжительности поездок', fontsize=18, fontweight='bold')
plt.xlabel('Продолжительность (минуты)', fontsize=12)
plt.ylabel('Количество поездок', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

mean_duration = ██████['duration'].mean()
median_duration = ██████['duration'].median()

plt.axvline(mean_duration, color='orange', linestyle='--', linewidth=2, label=f'Среднее: {mean_duration:.1f} м')
plt.axvline(mean_duration, color='blue', linestyle='--', linewidth=2, label=f'Медиана: {median_duration:.1f} м')

plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# В среднем одна поездка занимает 17–18 минут, большинство поездок укладываются в диапазон от 13.5 до 22 минут. Самая долгая поездка длилась почти 41 минуту. Внимательнее рассмотрим поездки, которые длились до минуты: это похоже на аномалии и стоит убедиться, короткие ли это поездки или какие-то сбои логирования.

# %%
display(██████[rides_go['duration'] < 1].sort_values(by='distance', ascending=False).head())
display(██████['user_id'][rides_go['duration'] < 1].count())
# Out:
#        user_id     distance  duration       date  month
# 16309     1411  7211.007745       0.5 2021-04-15      4
# 17242     1477  6724.932981       0.5 2021-01-12      1
# 11385     1057  6601.197575       0.5 2021-02-07      2
# 13701     1224  6414.516026       0.5 2021-07-15      7
# 14574     1285  6316.574814       0.5 2021-09-25      9
# 95

# %% [markdown]
# Да, похоже на сбои логирования: дистанции большие, а время маленькое.

# %% [markdown]
# ### Шаг 4. Объединение данных

# %% [markdown]
# #### 4.1 Создаем единый датафрейм

# %%
data = ██████.merge(users_go, on='user_id', how='left')
data = data.merge(██████, on='subscription_type', how='left')

# %% [markdown]
# Проверим, что после объединения таблиц не возникли пропуски и размер объъединенной таблицы соответствует ожиданиям.

# %%
if len(██████) == len(data):
    print('Размер объединенной таблицы соответствует ожиданиям.\nКоличество пропусков:',
          data.isna().sum(), sep='\n')
else:
    print('Размер объединенной таблицы не соответствует ожиданиям.\nКоличество пропусков:',
          data.isna().sum(), sep='\n')
# Out:
# Размер объединенной таблицы соответствует ожиданиям.
# Количество пропусков:
# user_id              0
# distance             0
# duration             0
# date                 0
# month                0
# name                 0
# age                  0
# city                 0
# subscription_type    0
# minute_price         0
# start_ride_price     0
# subscription_fee     0
# dtype: int64

# %% [markdown]
# Исправляем значения в колонке с временем у аномально быстрых поездок, а также округляем время для дальнейшего подсчета выручки.

# %%
for row in range(len(data)):
    if data.loc[row, 'duration'] < 1:
        data.loc[row, 'duration'] == data.loc[row, 'distance'] / ((data['distance']/data['duration']).mean())

data['duration'] = np.ceil(data['duration'])

# %% [markdown]
# #### 4.2 Делим пользователей с подпиской и без на разные датафреймы

# %%
data_ultra = data[data['subscription_type'] == 'ultra']
data_free = data[data['subscription_type'] == 'free']

# %% [markdown]
# #### 4.3  Визуализируем информацию о расстоянии и времени поездок для пользователей обеих категорий

# %%
mean_free = data_free['distance'].mean()
median_free = data_free['distance'].median()
mean_ultra = data_ultra['distance'].mean()
median_ultra = data_ultra['distance'].median()

plt.figure(figsize=(12, 6))

sns.histplot(data=data_free, x='distance', bins=50, color='#4CAF50', alpha=0.7, 
             element='step', stat='density', common_norm=False, label='Free')
plt.axvline(mean_free, color='#388E3C', linestyle='--', linewidth=2, label=f'Среднее Free: {mean_free:.0f} м')
plt.axvline(median_free, color='#1B5E20', linestyle='-', linewidth=2, label=f'Медиана Free: {median_free:.0f} м')


sns.histplot(data=data_ultra, x='distance', bins=50, color='#FF7043', alpha=0.7, 
             element='step', stat='density', common_norm=False, label='Ultra')
plt.axvline(mean_ultra, color='#E64A19', linestyle='--', linewidth=2, label=f'Среднее Ultra: {mean_ultra:.0f} м')
plt.axvline(median_ultra, color='#BF360C', linestyle='-', linewidth=2, label=f'Медиана Ultra: {median_ultra:.0f} м')

plt.title('Распределение расстояний поездок для пользователей free и ultra', fontsize=18, fontweight='bold')
plt.xlabel('Расстояние (метры)', fontsize=14)
plt.ylabel('Плотность', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(title="Тип подписки", fontsize=14, title_fontsize=14)

plt.show()

# %%
display(data_free['distance'].describe())
display(data_ultra['distance'].describe())
# Out:
# count    11568.000000
# mean      3045.495282
# std       1246.173806
# min          0.855683
# 25%       2366.562689
# 50%       3114.648465
# 75%       3905.697894
# max       7211.007745
# Name: distance, dtype: float64
# count    6500.000000
# mean     3115.445388
# std       836.895330
# min       244.210438
# 25%      2785.444017
# 50%      3148.637229
# 75%      3560.574425
# max      5699.769662
# Name: distance, dtype: float64

# %% [markdown]
# График и описательная статистика показывают, что пользователи с подпиской и без отличаются по поведению:
# 1. У пользователей с подпиской нет "ошибочно" коротких поездок
# 2. Размах дальности поездок у пользователей Ultra уже, чем у остальных
# 3. При этом средняя поездка у пользователей Ultra на 70 м. длиннее
# 4. Есть небольшой подъем графика в районе 1 км, поскольку у платных клиентов стоимость старта бесплатная.
# 5. Поездки на "дальние" расстояния пользователи с подпиской совершают реже.

# %%
mean_free = data_free['duration'].mean()
median_free = data_free['duration'].median()
mean_ultra = data_ultra['duration'].mean()
median_ultra = data_ultra['duration'].median()

plt.figure(figsize=(12, 6))

sns.histplot(data=data_free, x='duration', bins=10, color='#4CAF50', alpha=0.7, 
             element='step', stat='density', common_norm=False, label='Free')
plt.axvline(mean_free, color='#388E3C', linestyle='--', linewidth=2, label=f'Среднее Free: {mean_free:.0f} м')
plt.axvline(median_free, color='#1B5E20', linestyle='-', linewidth=2, label=f'Медиана Free: {median_free:.0f} м')


sns.histplot(data=data_ultra, x='duration', bins=10, color='#FF7043', alpha=0.7, 
             element='step', stat='density', common_norm=False, label='Ultra')
plt.axvline(mean_ultra, color='#E64A19', linestyle='--', linewidth=2, label=f'Среднее Ultra: {mean_ultra:.0f} м')
plt.axvline(median_ultra, color='#BF360C', linestyle='-', linewidth=2, label=f'Медиана Ultra: {median_ultra:.0f} м')


# Настраиваем заголовок и подписи осей
plt.title('Распределение продолжительности поездок для пользователей free и ultra', fontsize=18, fontweight='bold')
plt.xlabel('Продолжительность (минуты)', fontsize=14)
plt.ylabel('Плотность', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(title="Тип подписки", fontsize=14, title_fontsize=14)

plt.show()

# %%
display(data_free['duration'].describe())
display(data_ultra['duration'].describe())
# Out:
# count    11568.000000
# mean        17.890992
# std          6.330250
# min          1.000000
# 25%         13.000000
# 50%         18.000000
# 75%         22.000000
# max         35.000000
# Name: duration, dtype: float64
# count    6500.000000
# mean       19.037692
# std         5.577439
# min         4.000000
# 25%        15.000000
# 50%        19.000000
# 75%        22.000000
# max        41.000000
# Name: duration, dtype: float64

# %% [markdown]
# Здесь большой разницы в поведении пользователей нет, о чем свидетельствуют похожие очертания графиков. Разве что снова подтверждается, что "ошибочных" поездок у юзеров с подпиской нет.

# %% [markdown]
# ### Шаг 5. Подсчёт выручки

# %% [markdown]
# #### 5.1 Найдем суммарное расстояние, количество поездок и суммарное время для каждого пользователя за каждый месяц.

# %%
revenue_data = data.pivot_table(
    index=('user_id', 'month', 'subscription_type', 'start_ride_price', 'minute_price', 'subscription_fee'),
    values=('distance', 'duration'),
    aggfunc=('sum', 'count'))

# %%
revenue_data.columns = ['rides', 'distance', 'to_drop', 'duration']
revenue_data = revenue_data[['rides', 'distance', 'duration']].reset_index()
revenue_data.head()
# Out:
#    user_id  month subscription_type  start_ride_price  minute_price  \
# 0        1      1             ultra                 0             6
# 1        1      4             ultra                 0             6
# 2        1      8             ultra                 0             6
# 3        1     10             ultra                 0             6
# 4        1     11             ultra                 0             6
#
#    subscription_fee  rides     distance  duration
# 0               199      2  7027.511294      42.0
# 1               199      1   754.159807       7.0
# 2               199      2  6723.470560      46.0
# 3               199      2  5809.911100      32.0
# 4               199      3  7003.499363      56.0

# %% [markdown]
# #### 5.2. Добавим столбец с помесячной выручкой, которую принёс каждый пользователь

# %%
revenue_data['monthly_revenue'] = ((revenue_data['start_ride_price'] * revenue_data['rides']) + \
(revenue_data['minute_price'] * revenue_data['duration']) + revenue_data['subscription_fee'])
revenue_data['monthly_revenue'] = np.ceil(revenue_data['monthly_revenue'])
revenue_data.head()
# Out:
#    user_id  month subscription_type  start_ride_price  minute_price  \
# 0        1      1             ultra                 0             6
# 1        1      4             ultra                 0             6
# 2        1      8             ultra                 0             6
# 3        1     10             ultra                 0             6
# 4        1     11             ultra                 0             6
#
#    subscription_fee  rides     distance  duration  monthly_revenue
# 0               199      2  7027.511294      42.0            451.0
# 1               199      1   754.159807       7.0            241.0
# 2               199      2  6723.470560      46.0            475.0
# 3               199      2  5809.911100      32.0            391.0
# 4               199      3  7003.499363      56.0            535.0

# %% [markdown]
# ### Шаг 6. Проверка гипотез

# %% [markdown]
# #### 6.1 Tратят ли пользователи с подпиской больше времени на поездки?
#
# Сформулируем гипотезы для этого вопроса:
# - H0: Пользователи с подпиской тратят на поездки **столько же** времени, сколько пользователи без подписки.
# - H1: Пользователи с подпиской тратят на поездки **больше** времени, чем пользователи без подписки.
#
# *Код ниже будет проверять одностороннюю гипотезу о том, что среднее время без подписки меньше, чем среднее время с подпиской.*

# %%
print('Среднее время пользователей с подпиской:', data_ultra['duration'].mean())
print('Среднее время пользователей без подписки:', data_free['duration'].mean())

alpha = 0.05

results = st.ttest_ind(data_ultra['duration'], data_free['duration'], alternative='greater')

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# Среднее время пользователей с подпиской: 19.037692307692307
# Среднее время пользователей без подписки: 17.890992392807746
# p-значение: 2.4959453720736625e-34
# Отвергаем нулевую гипотезу

# %% [markdown]
# **Вывод:** пользователи с подпиской тратят значимо больше времени на поездки.

# %% [markdown]
# #### 6.2 Можно ли сказать, что среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает 3130 метров?
#
# Сформулируем гипотезы для этого вопроса:
# - H0: Среднее расстояние за одну поездку **равно** 3130 метров.
# - H1: Среднее расстояние за одну поездку **больше** 3130 метров.
#
# *Код ниже будет проверять одностороннюю гипотезу о том, что среднее расстояние больше, чем 3130 метров.*

# %%
print('Среднее расстояние за одну поездку у пользователей с подпиской:', data_ultra['distance'].mean())

value = 3130
alpha = 0.05

results = st.ttest_1samp(data_ultra['distance'], value, alternative='greater')

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# Среднее расстояние за одну поездку у пользователей с подпиской: 3115.4453880370247
# p-значение: 0.9195368847849785
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# **Вывод:** да, действительно, среднее расстояние поездки пользователей с подпиской не превышает 3130 метров.

# %% [markdown]
# #### 6.3 Будет ли помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки?
#
# Сформулируем гипотезы для этого вопроса:
# - H0: Помесячная выручка от пользователей с подпиской **равна** выручке от пользователей без подписки.
# - H1: Помесячная выручка от пользователей с подпиской **выше**, чем выручка от пользователей без подписки.
#
# *Код ниже будет проверять одностороннюю гипотезу о том, что выручка от пользователей с подпиской больше, чем без подписки.*

# %%
ultra_revenue = revenue_data.loc[revenue_data['subscription_type'] == 'ultra', 'monthly_revenue']
free_revenue = revenue_data.loc[revenue_data['subscription_type'] == 'free', 'monthly_revenue']

print('Средняя помесячная выручка пользователей с подпиской:', np.ceil(ultra_revenue.mean()))
print('Средняя помесячная выручка пользователей без подписки:', np.ceil(free_revenue.mean()))

alpha = 0.05

results = st.ttest_ind(ultra_revenue, free_revenue, equal_var = False, alternative='greater')

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# Средняя помесячная выручка пользователей с подпиской: 363.0
# Средняя помесячная выручка пользователей без подписки: 329.0
# p-значение: 8.874140893976874e-40
# Отвергаем нулевую гипотезу

# %% [markdown]
# **Вывод**: да, средняя помесячная выручка пользователей с подпиской выше, чем без нее. Нужно увеличивать количество клиентов Ultra, чтобы бизнес рос.

# %% [markdown]
# #### 6.4 Представьте такую ситуацию: техническая команда сервиса обновила сервера, с которыми взаимодействует мобильное приложение. Она надеется, что из-за этого количество обращений в техподдержку значимо снизилось. Некоторый файл содержит для каждого пользователя данные о количестве обращений до обновления и после него. Какой тест вам понадобился бы для проверки этой гипотезы?
#
# Понадобился бы двухвыборочный t-тест для зависимых выборок. Причем выборки обязательно должны быть одного размера и согласованы друг с другом: первое число в каждой выборке — это измерения до и после для первого объекта, второе — для второго и так далее.
#
# Гипотезы формулируются так:
# - H0: Количество обращений в техподдержку не изменилось.
# - H1: Количество обращений в техподдержку значимо снизилось

# %% [markdown]
# ### Шаг 7. Распределения

# %% [markdown]
# #### 7.1. Определяем количество промокодов
#
# Отделу маркетинга ██████ поставили задачу: нужно провести акцию с раздачей промокодов на один бесплатный месяц подписки, в рамках которой как минимум 100 существующих клиентов должны продлить эту подписку. То есть по завершении периода действия подписки пользователь может либо отказаться от неё, либо продлить, совершив соответствующий платёж. \
# \
# Эта акция уже проводилась ранее и по итогу выяснилось, что после бесплатного пробного периода подписку продлевают 10% пользователей.\
# \
# **Вопрос:** какое минимальное количество промокодов нужно разослать, чтобы вероятность не выполнить план была примерно 5%?

# %%
n = 0
p = 0.1
k = 99

while st.binom(n, p).cdf(k) > 0.05:
    n += 1
    
print(f'Вероятность не выполнить план при раздаче {n} промокодов равна {st.binom(n, p).cdf(k):.0%}.')
# Out:
# Вероятность не выполнить план при раздаче 1161 промокодов равна 5%.

# %%
n = 1161
p = 0.1
x = range(n + 1)

# Значения для оси y (вероятность)
y = binom.pmf(x, n, p)

# Построение графика
plt.figure(figsize=(12, 6))
plt.plot(x, y, color='#4CAF50', linewidth=2)
plt.fill_between(x, y, color='#4CAF50', alpha=0.6)

plt.title('Биномиальное распределение (n=1161, p=0.1)', fontsize=18, fontweight='bold')
plt.xlabel('Количество успехов', fontsize=14)
plt.ylabel('Вероятность', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

mean = n * p
plt.axvline(mean, color='orange', linestyle='--', linewidth=2, label=f'Среднее: {mean:.1f}')
plt.axvline(binom.median(n, p), color='blue', linestyle='-', linewidth=2, label=f'Медиана: {binom.median(n, p):.1f}')

plt.legend(fontsize=12)
plt.show(), mean, binom.median(n, p)
# Out:
# (None, 116.10000000000001, 116.0)

# %% [markdown]
# #### 7.2 Прогнозируем открытие уведомлений
#
# Отдел маркетинга рассылает клиентам push-уведомления в мобильном приложении. Клиенты могут открыть его или не открывать. Известно, что уведомления открывают около 40 % получивших клиентов. Отдел планирует разослать 1 млн уведомлений. \
# \
# **Задача:** оцените вероятность того, что уведомление откроют не более 399,5 тыс. пользователей.

# %%
# задаем параметры биномиального распределения
n = 1000000
p = 0.4
k = 399500

# считаем вероятность хвоста слева от 399500 кликов
result = st.binom(n, p).cdf(k)
print(f'Вероятность, что уведомление откроют меньше {k} пользователей, равна {result:.0%}.')
# Out:
# Вероятность, что уведомление откроют меньше 399500 пользователей, равна 15%.

# %%
n = 1000000
p = 0.4
x = range(n + 1)

# Значения для оси y (вероятность)
y = binom.pmf(x, n, p)

# Построение графика
plt.figure(figsize=(12, 6))
plt.plot(x, y, color='#4CAF50', linewidth=2)
plt.fill_between(x, y, color='#4CAF50', alpha=0.6)

plt.title('Биномиальное распределение (n=1000000, p=0.4)', fontsize=18, fontweight='bold')
plt.xlabel('Количество успехов', fontsize=14)
plt.ylabel('Вероятность', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

mean = n * p
plt.axvline(mean, color='orange', linestyle='--', linewidth=2, label=f'Среднее: {mean:.1f}')
plt.axvline(binom.median(n, p), color='blue', linestyle='-', linewidth=2, label=f'Медиана: {binom.median(n, p):.1f}')

plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# ### Выводы

# %% [markdown]
# **Обработка данных**:
# - `██████` – информация о клиентах. Пропусков нет, удален 31 дубликат.
# - `██████` – информация о поездках. Пропусков и дубликатов нет, время в аномально быстрых поездках заменено рассчитанным по средней скорости.
# - `██████`– информация о подписках. Пропусков и дубликатов нет.
#
# **Исследовательский анализ данных**:
# - Больше всего пользователей сервиса в Пятигорске, на последнем месте — Москва.
# - Пользователей без подписки больше, чем с подпиской (54% против 46%).
# - Минимальный возраст пользователей сервиса - 12 лет, максимальный - 43 года. Чаще всего самокатами пользуются люди в возрасте от 22 до 28 лет.
# - Чаще всего поездки клиентов укладываются в диапазон от 2543 до 3776 м. Средняя дистанция – 3133 м.
# - В среднем одна поездка занимает 17–18 минут, большинство поездок укладываются в диапазон от 13.5 до 22 минут.
#
# **Объединение данных**:
# - Cоздан единый датафрейм со всей информацией о пользователях, поездках и подписках, а также два отдельных датафрейма для тарифов free и ultra.
# - График и описательная статистика показали, что пользователи с подпиской и без отличаются по поведению:
#     1. У пользователей с подпиской нет "ошибочно" коротких поездок
#     2. Размах дальности поездок у пользователей Ultra уже, чем у остальных
#     3. При этом средняя поездка у пользователей Ultra на 70 м. длиннее
#     4. Есть небольшой подъем графика в районе 1 км, поскольку у платных клиентов стоимость старта бесплатная.
#     5. Поездки на "дальние" расстояния пользователи с подпиской совершают реже.
#
# **Подсчет выручки**:
# - Агрегировали информацию о расстоянии, количестве поездок и суммарном времени для каждого пользователя за каждый месяц.
# - Добавили расчет помесячной выручки, которую принёс каждый пользователь.
#
# **Исследовательские вопросы**: \
# \
# Q1: *Тратят ли пользователи с подпиской больше времени на поездки?* \
# A1: *Да*, пользователи с подпиской тратят значимо больше времени на поездки. \
# \
# *Q2: Расстояние одной поездки в 3130 метров — оптимальное с точки зрения износа самоката. Можно ли сказать, что среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает 3130 метров?* \
# A2: *Нет*, среднее расстояние одной поездки не угрожает износу самокатов. \
# \
# *Q3: Будет ли помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки?* \
# A3: *Да*, пользователи с подпиской выгоднее для бизнеса и с этой точки зрения, поэтому нужно увеличить продажи подписок. \
# \
# Q4: *Какое минимальное количество промокодов нужно разослать, чтобы вероятность не выполнить план была примерно 5%?* \
# A4: 1161 промокод.\
# \
# Q5: *Какова вероятность того, что уведомление откроют не более 399,5 тыс. пользователей?* \
# A5: 15%
